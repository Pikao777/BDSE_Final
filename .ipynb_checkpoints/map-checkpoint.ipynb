# %%
import pandas as pd
import folium
from folium import plugins
import json

# %%
park_map = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=10, control_scale=True,)
# 範例化 folium.map.FeatureGroup 物件
incidents = folium.map.FeatureGroup()
for name,row in df.iterrows():
    incidents.add_child(
        folium.Marker(            
            (row["latitude"], row["longitude"]),   # 每個停車場的經緯度座標
            color='#FF1493',            # 標誌的外圈顏色
            fill=True,                  # 是否填充
            fill_color='#00FF00',       # 填充顏色
            fill_opacity=0.4            # 填充透明度
        )
    )

park_map.add_child(incidents)
park_map.save('test_map3.html')

# %%
from folium import plugins

# data = pd.read_csv('parkings.csv', encoding='gbk')
park_map = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=10, control_scale=True,)
marker_cluster = plugins.MarkerCluster().add_to(park_map)


for name,row in df.iterrows():
    folium.Marker(location=[row["latitude"], row["longitude"]]).add_to(marker_cluster)
park_map.save('test_map3.html')

# %%
import pandas as pd
import folium
from folium import plugins
import json
df = pd.read_csv('cool.csv')
df = df[0:2]
df
# Out:
#    Unnamed: 0                                         google_url place_name  \
# 0           0  https://www.google.com.tw/maps/place/%E9%BB%91...       黑曜麵屋
# 1           1  https://www.google.com.tw/maps/place/%E6%A8%82...     樂山窄巷拉麵
#
#    total_rating place_category  total_reviews cost              address  \
# 0           4.1            拉麵店          379.0    $   112台北市北投區尊賢街206巷2號
# 1           4.1            拉麵店         1681.0   $$      112台北市北投區大同街27號
#
#                      district  eat_in  ...  \
# 0  Plus Code: 4G85+47 北投區 台北市       1  ...
# 1  Plus Code: 4FMX+5J 北投區 台北市       1  ...
#
#                                    website          phone  close  \
# 0  https://www.facebook.com/Obsidianhouse/   0979 047 907    NaN
# 1     https://www.facebook.com/rakuzan428/   02 2892 6265    NaN
#
#   place_acquisition_date file_name_1 category_new  district_new  \
# 0             2022-11-22           0           日式           北投區
# 1             2022-11-22           1           日式           北投區
#
#                        location   latitude   longitude
# 0  ['25.115294', '121.5081886']  25.115294  121.508189
# 1   ['25.132952', '121.499027']  25.132952  121.499027
#
# [2 rows x 24 columns]

# %%
df = pd.read_csv('cool.csv')
df = df[6:8]
df
# Out:
#    Unnamed: 0                                         google_url  \
# 6           6  https://www.google.com.tw/maps/place/%E6%BB%BF...
# 7           7  https://www.google.com.tw/maps/place/%E9%95%B7...
#
#                                          place_name  total_rating  \
# 6  滿足溫泉拉麵/北投拉麵/北投美食/北投餐廳/北投必吃//北投Restaurants/台北美食推薦           3.8
# 7                                         長生塩人 北投車站           4.6
#
#   place_category  total_reviews cost               address  \
# 6            拉麵店          776.0  NaN      112台北市北投區中山路1之8號
# 7            拉麵店          726.0  NaN   112009台北市北投區育仁路8巷3號
#
#                      district  eat_in  ...  \
# 6  Plus Code: 4GP3+RW 北投區 台北市       1  ...
# 7  Plus Code: 4FMX+3F 北投區 台北市       1  ...
#
#                                  website          phone  close  \
# 6                https://manzuramen.com/   02 2897 8366    NaN
# 7  https://www.facebook.com/thesaltramen   0987 299 379    NaN
#
#   place_acquisition_date file_name_1 category_new  district_new  \
# 6             2022-11-22           6           日式           北投區
# 7             2022-11-22           7           日式           北投區
#
#                         location   latitude   longitude
# 6   ['25.1370212', '121.504872']  25.137021  121.504872
# 7  ['25.1327138', '121.4987251']  25.132714  121.498725
#
# [2 rows x 24 columns]

# %%
import pandas as pd
import folium
from folium import plugins
import json

df = pd.read_csv('cool.csv')
df = df[0:10]

m = folium.Map(tiles="OpenStreetMap", location=[df['latitude'].mean(), df['longitude'].mean()], zoom_start=13)
# marker_cluster = plugins.MarkerCluster().add_to(m)

for i in range(len(df)):
#     profiles = ''
#     for info in df.loc[i,['place_name','total_reviews','total_rating','address']]:
#         item = '<{0}>{1}</{0}>'.format('li',info)
#         profiles += item
    #print(profiles)
    html=f"""
        <h1>{df.iloc[i]['place_name']}</h1>
        <p>Infomation:</p> 
        <ul>
        <li>總評論數: <span style="color: red; font-weight:bold;">{int(df.loc[i,'total_reviews'])}</span> 筆</li>
        <li>平均星數: <span style="color: red; font-weight:bold;">{int(df.loc[i,'total_rating'])}</span></li>
        <li>地址: {df.loc[i,'address']}</li>
        </ul>
        </p>
        <p>Google Maps <a href="{df.iloc[i]['google_url']}" target = "_blank">link </a></p>
        """
    
    iframe = folium.IFrame(html=html, width=300, height=250)
    popup = folium.Popup(iframe, max_width=2650)
    folium.Marker(
        location=[df.iloc[i]['latitude'], df.iloc[i]['longitude']],
        popup=popup,
#         icon=folium.DivIcon(html=f"""
#             <div><svg>
#                 <circle cx="5" cy="5" r="4" fill="#69b3a2" opacity="0.7"/>
#                 <rect x="3", y="3" width="3" height="3", fill="red", opacity=".7" 
#             </svg></div>""")
    ).add_to(m)

with open("台北界線.json", encoding='utf-8') as file:
    data = json.load(file)

m.add_child(folium.GeoJson(data = data))

m.save('test_map4.html')

# %%
import folium

# Create a map object
m = folium.Map(location=[45.5236, -122.6750], zoom_start=13)

# Add the two points that you want to connect with the arrow
point1 = [45.5236, -122.6750]
point2 = [45.5236, -122.6623]

# Use folium.PolyLine to draw the arrow between the two points
folium.PolyLine([point1, point2], color='red', weight=2.5, opacity=1, popup='Arrow').add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fc343b96addb1115f9f2b38d97d1c3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fc343b96addb1115f9f2b38d97d1c3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fc343b96addb1115f9f2b38d97d1c3d = L.map(
#                 &quot;map_4fc343b96addb1115f9f2b38d97d1c3d&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_397391e8b65b87d681ad12a2307b8d70 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4fc343b96addb1115f9f2b38d97d1c3d);
#
#
#             var poly_line_70d30b22036956d9985a41415619fecb = L.polyline(
#                 [[45.5236, -122.675], [45.5236, -122.6623]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;4, 8&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_4fc343b96addb1115f9f2b38d97d1c3d);
#
#
#         var popup_793a65a3b723ed1350dd1bd2e1c744f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27176d792cbbd1da2e18b109a82c47af = $(`&lt;div id=&quot;html_27176d792cbbd1da2e18b109a82c47af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arrow&lt;/div&gt;`)[0];
#                 popup_793a65a3b723ed1350dd1bd2e1c744f8.setContent(html_27176d792cbbd1da2e18b109a82c47af);
#
#
#
#         poly_line_70d30b22036956d9985a41415619fecb.bindPopup(popup_793a65a3b723ed1350dd1bd2e1c744f8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import numpy as np
# Create a map object
m = folium.Map(location=[45.5236, -122.6750], zoom_start=13)

# Add the two points that you want to connect with the arrow
point1 = [45.5236, -122.6750]
point2 = [45.5236, -122.6623]

# Calculate the angle of the arrowhead marker
angle = np.rad2deg(np.arctan2(point2[1]-point1[1], point2[0]-point1[0]))

# Use folium.RegularPolygonMarker to create the arrowhead marker
folium.RegularPolygonMarker(point1, popup='Arrowhead Marker', fill_color='#132b5e',
                            number_of_sides=3, radius=10, rotation=angle).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19ee5fa33a4dced6c79540e5cf679790 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19ee5fa33a4dced6c79540e5cf679790&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19ee5fa33a4dced6c79540e5cf679790 = L.map(
#                 &quot;map_19ee5fa33a4dced6c79540e5cf679790&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0307647b0c0e36be77372b3d49452ac4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19ee5fa33a4dced6c79540e5cf679790);
#
#
#             var regular_polygon_marker_4109116af815a7bec24472beb884b6c1 = new L.RegularPolygonMarker(
#                 [45.5236, -122.675],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#132b5e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;rotation&quot;: 90.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19ee5fa33a4dced6c79540e5cf679790);
#
#
#         var popup_52cc88681c6edcc4cabd2df7db1eac45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe94dbb953bfa7ce141a31665eceee76 = $(`&lt;div id=&quot;html_fe94dbb953bfa7ce141a31665eceee76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arrowhead Marker&lt;/div&gt;`)[0];
#                 popup_52cc88681c6edcc4cabd2df7db1eac45.setContent(html_fe94dbb953bfa7ce141a31665eceee76);
#
#
#
#         regular_polygon_marker_4109116af815a7bec24472beb884b6c1.bindPopup(popup_52cc88681c6edcc4cabd2df7db1eac45)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pip install number_of_sidesmpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement number_of_sidesmpy (from versions: none)
# ERROR: No matching distribution found for number_of_sidesmpy
